# %%
import numpy as np
import matplotlib.pyplot as plt
fig = plt.figure()

# %%
ax1 = fig.add_subplot(2, 2, 1)

# %%
ax2 = fig.add_subplot(2, 2, 2)
plt.show(ax2)

# %%
fig = plt.figure()
ax1 = fig.add_subplot(2, 2, 1)
ax2 = fig.add_subplot(2, 2, 2)
ax1.hist(np.random.randn(100), bins=20, color='k', alpha=1)
ax2.scatter(np.arange(30), np.arange(30)+ 3*np.random.randn(30))

# %%
fig, axes = plt.subplots(2, 3, sharex=True, sharey=True)

# %%
fig, axes = plt.subplots(2, 3, sharex=True, sharey=True)
axes[1, 2].plot(np.random.randn(30).cumsum(), 'ko--')

# %%
data = np.random.randn(30).cumsum()
plt.plot(data, 'g--', label='solid')
plt.plot(data, 'c-', drawstyle='steps-post', label='ladder')
plt.legend(loc='best')

# %%
plt.plot(np.random.randn(50), 'c-')
plt.xticks([10, 20, 30, 40])
plt.xlabel(['one', 'two', 'three', 'four'], rotation=40, fontsize='large')
plt.title('fuck you plot')
plt.text(1, 1, 'hellow world', family='monospace', fontsize=10)
# Out:
# Text(1, 1, 'hellow world')

# %%
import pandas as pd
from datetime import datetime
fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)
data = pd.read_csv('example/spx.csv', index_col=0, parse_dates=True)
spx = data['SPX']
spx.plot(ax=ax, style='k-')
crisis_data = [
    (datatime(2007, 10, 11), 'Peak of bull market'),
    (datatime(2008, 3, 12), 'Bear stearns fails'),
    (datatime(2008, 9, 15), 'Lehman Bankruptcy')
]
for date, label in crisis_data:
    ax.annotate(label, xy=(data, spx.asof(date) + 75),
               xytext=(date, spx.asof(date) + 225),
               arrowprops=dict(facecolor='black', headwidth=4, width=2,
                              headlenth=4), horizontalalignment='left',
               verticalalignment='top')
ax.set_xlim(['1/1/2007', '1/1/2011'])
ax.set.ylim([600, 1000])
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-106-d7df784dc1dc> in <module>
#       3 fig = plt.figure()
#       4 ax = fig.add_subplot(1, 1, 1)
# ----> 5 data = pd.read_csv('example/spx.csv', index_col=0, parse_dates=True)
#       6 spx = data['SPX']
#       7 spx.plot(ax=ax, style='k-')
#
# ...

# %%
a = np.random.randn(10, 4)

# %%
fig, axes = plt.subplots(2, 1)
data = pd.Series(np.random.rand(5), index=list('abcde'))
data.plot.bar(ax=axes[0], color='c', alpha=0.5)

# %%
df = pd.DataFrame(np.random.rand(6, 4))

# %%
df
# Out:
#           0         1         2         3
# 0  0.069170  0.750615  0.109489  0.265821
# 1  0.941318  0.916552  0.143361  0.390510
# 2  0.783197  0.595730  0.534379  0.186957
# 3  0.162279  0.927883  0.931639  0.765071
# 4  0.093575  0.833441  0.628672  0.232044
# 5  0.332046  0.275935  0.257063  0.574821

# %%
df.plot.barh(stacked=True, alpha=0.8)
