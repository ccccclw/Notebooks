# %% [markdown]
# ## Exam 3
#
# 1.
#
# a) $[He]2s^22p^5 \rightarrow { }^{2} \mathrm{P}_{3 / 2}$ and ${ }^{2} \mathrm{P}_{1 / 2}$
#
# $np^5$ configuration can be thought of as an $np^1$ configuration because two of the np orbitals are occupied and $M_s$ and $M_L$ are determined by the rest of half-filled p-orbital.
#
# For $np^1$
#
# $$
# \begin{array}{rrrrr}
# m_{l} & m_{s} & M_{L} & M_{S} & M_{J} \\
# \hline 1 & +\frac{1}{2} & 1 & +\frac{1}{2} & +\frac{3}{2} \\
# 1 & -\frac{1}{2} & 1 & -\frac{1}{2} & +\frac{1}{2} \\
# 0 & +\frac{1}{2} & 0 & +\frac{1}{2} & +\frac{1}{2} \\
# 0 & -\frac{1}{2} & 0 & -\frac{1}{2} & -\frac{1}{2} \\
# -1 & +\frac{1}{2} & -1 & +\frac{1}{2} & -\frac{1}{2} \\
# -1 & -\frac{1}{2} & -1 & -\frac{1}{2} & -\frac{3}{2}
# \end{array}
# $$
#
# we get ${ }^{2} \mathrm{P}$ with $J = \frac{1}{2}, \frac{3}{2}$
#
# b) $[He]2s^12p^1 \rightarrow { }^{3} \mathrm{P}_{2}; { }^{3} \mathrm{P}_{1}; { }^{3} \mathrm{P}_{0}; { }^{1} \mathrm{P}_{1}$
#
# $$
# \begin{array}{rrrrrrr}
# m_{1 l} & m_{1 s} & m_{2 l} & m_{2 s} & M_{L} & M_{S} & M_{J} \\
# \hline 0 & +\frac{1}{2} & 1 & +\frac{1}{2} & 1 & 1 & 2 \\
# 0 & -\frac{1}{2} & 1 & +\frac{1}{2} & 1 & 0 & 1 \\
# 0 & +\frac{1}{2} & 1 & -\frac{1}{2} & 1 & 0 & 1 \\
# 0 & -\frac{1}{2} & 1 & -\frac{1}{2} & 1 & -1 & 0 \\
# 0 & +\frac{1}{2} & 0 & +\frac{1}{2} & 0 & 1 & 1 \\
# 0 & -\frac{1}{2} & 0 & +\frac{1}{2} & 0 & 0 & 0 \\
# 0 & +\frac{1}{2} & 0 & -\frac{1}{2} & 0 & 0 & 0 \\
# 0 & -\frac{1}{2} & 0 & -\frac{1}{2} & 0 & -1 & -1 \\
# 0 & +\frac{1}{2} & -1 & +\frac{1}{2} & -1 & 1 & 0 \\
# 0 & -\frac{1}{2} & -1 & +\frac{1}{2} & -1 & 0 & -1 \\
# 0 & +\frac{1}{2} & -1 & -\frac{1}{2} & -1 & 0 & -1 \\
# 0 & -\frac{1}{2} & -1 & -\frac{1}{2} & -1 & -1 & -2
# \end{array}
# $$
#
# c) $[Ne]3s^23p^63d^9 \rightarrow { }^{2} \mathrm{D}_{5/2}; { }^{2} \mathrm{D}_{3/2}$
#
# Equivalent with $[Ne]3s^23p^63d^1$
#
# 2.$\space$$C_{3h}:$ $C_3$ passing through the center $+ \sigma_h$ plane perpendicular with $C_3$
#
# 3.$\space$ $\psi=c_{1} e^{-x}+c_{2} e^{-2 x}$
#
# $H_{i j}=\int f_{i} \hat{H} f_{j} d \tau$; $S_{i j}=S_{j i}=\int f_{i} f_{j} d \tau$
#
# $H_{11}=\int_{0}^{l} f_{1} \hat{H} f_{1} d x = \frac{\hbar^2}{4m}(e^{-2l}-1)$; $S_{1 1}=\int_{0}^{l} f_{1} f_{1} d x = \frac{1}{2}(1 - e^{-2l})$
#
# $H_{22}=\int_{0}^{l} f_{2} \hat{H} f_{2} d x = \frac{\hbar^2}{2m}(e^{-4l}-1)$; $S_{2 2}=\int_{0}^{l} f_{2} f_{2} d x = \frac{1}{4}(1 - e^{-4l})$
#
# $H_{12}=\int_{0}^{l} f_{1} \hat{H} f_{2} d x = \frac{2\hbar^2}{3m}(e^{-3l}-1)$; $S_{1 2}=\int_{0}^{l} f_{1} f_{2} d x = \frac{1}{3}(1 - e^{-3l})$
#
# $H_{21}=\int_{0}^{l} f_{2} \hat{H} f_{1} d x = \frac{\hbar^2}{6m}(e^{-3l}-1)$; $S_{1 2}=\int_{0}^{l} f_{1} f_{2} d x = \frac{1}{3}(1 - e^{-3l})$
#
# $\left|\begin{array}{cc}H_{11}-E S_{11} & H_{12}-E S_{12} \\ H_{21}-E S_{21} & H_{22}-E S_{22}\end{array}\right|=0 \rightarrow $
#
# $\frac{\hbar^{2}}{4 m}\left(e^{-2 l}-1\right) \frac{\hbar^{2}}{2 m}\left(e^{-4 l}-1\right)-(\frac{\hbar^{2}}{4 m}\left(e^{-2 l}-1\right) \left(-\frac{1}{4}\left(e^{-4 l}-1\right)\right)+\frac{\hbar^{2}}{2 m}\left(e^{-4 l}-1\right) \left(-\frac{1}{2}\left(e^{-2 l}-1\right)\right))E+\left(\frac{1}{4}\left(e^{-4 l}-1\right)\right)\left(\frac{1}{2}\left(e^{-2 l}-1\right)\right)E^{2}-\frac{\hbar^{2}}{6 m}\left(e^{-3 l}-1\right) \frac{2 \hbar^{2}}{3 m}\left(e^{-3 l}-1\right)+(\frac{\hbar^{2}}{6 m}\left(e^{-3 l}-1\right) \left(-\frac{1}{3}\left(e^{-3 l}-1\right)\right)+\frac{2 \hbar^{2}}{3 m}\left(e^{-3 l}-1\right) \left(-\frac{1}{3}\left(e^{-3 l}-1\right)\right))E-\left(-\frac{1}{3}\left(e^{-3 l}-1\right)\right)^{2}E^{2}=0$
#
# $\left(\frac{\left(e^{-2 l}-1\right)\left(e^{-4 l}-1\right)}{8}-\frac{\left(\left(e^{-3 l}-1\right)\right)^{2}}{9}\right)\left(\frac{\hbar^{4}}{m^{2}}+\frac{5 \hbar^{2}}{2 m} E+E^{2}\right)=0$
#
# $E = min\{-\frac{\hbar^{2}}{2m}, -\frac{2\hbar^{2}}{m}\} = -\frac{2\hbar^{2}}{m}$
#
# As we know that $E > 0$, this variational result seems not to be a right bound. By just checking the condition of the wavefunction required for such system:
#
# $P_0 = \lim _{x \rightarrow 0}\left(c_{1} e^{-x}+c_{2} e^{-2 x}\right)^{2}=\left(c_{1}+c_{2}\right)^{2} \neq 0$
#
# $P_l = \lim _{x \rightarrow l}\left(c_{1} e^{-x}+c_{2} e^{-2 x}\right)^{2}=\left(c_{1} e^{-l}+c_{2} e^{-2 l}\right)^2 \neq 0$
#
# we find that this is not an appropriate trial function.
#
# 4.$\space$ $H=-\frac{\hbar^{2}}{2 m} \frac{d^{2}}{d x^{2}}+\frac{1}{2} k\left(x+x^{2}\right) =-\frac{\hbar^{2}}{2 m} \frac{d^{2}}{d x^{2}}+\frac{1}{2} kx^{2}+\frac{1}{2} kx = H^0_{1D-HO} + \frac{1}{2} kx$
#
# $\Delta E=\int \psi^{(0) *} \hat{H}^{(1)} \psi^{(0)} d \tau = \frac{k}{2}\left(\frac{\alpha}{\pi}\right)^{1 / 2}\int_{-\infty}^{\infty} e^{-\alpha x^{2} / 2}\left( x \space e^{-\alpha x^{2} / 2}\right) d x = \left(\frac{\alpha}{\pi}\right)^{1 / 2}\frac{k}{2} \int_{-\infty}^{\infty} x e^{-\alpha x^{2}} d x = 0$
#
# $E = E_0 + \Delta E = \frac{h \nu}{2}$

# %% [markdown]
# ## HW7
#
# 1.$\space$ $$
# \begin{array}{l|lll}
# C_{3 v} & E & 2 C_{3} & 3 \sigma_{v} \\
# \hline A_{1} & 1 & 1 & 1 \\
# A_{2} & 1 & 1 & -1 \\
# E & 2 & -1 & 0
# \end{array}
# $$
#
# $$
# \begin{array}{l|lll}
# C_{3 v} & E & C_{3} & \sigma_{v} \\
# \hline \text {atoms} & 4 & 1 & 2 \\
# \chi(\text {per atom}) & 3 & 0 & 1 \\
# \hline \Gamma\left(NH_{3}\right) & 12 & 0 & 2
# \end{array}
# $$
#
# $$
# \begin{array}{l}
# n_{A_{1}}=\frac{1}{6}[(1 \cdot 12 \cdot 1)+(2 \cdot 0 \cdot 1)+(3 \cdot 2 \cdot 1)] = 3 \\
# n_{A_{2}}=\frac{1}{6}[(1 \cdot 12 \cdot 1)+(3 \cdot 2 \cdot-1)]=1 \\
# n_{E}=\frac{1}{6}[(2 \cdot 12 \cdot 1)+(3 \cdot 2 \cdot 0)]=4 \\
# \quad \Gamma\left(N H_{3}\right)=3 A_{1}+1 A_{2}+4 E
# \end{array}
# $$
#
# 2.$\space$ core 1s orbital is sum of 6 gaussians;
#    valence shell 2s and 2p orbitals are split into three parts: 1) contracted part is sum of 3 gaussians; 2) more diffuse part is 1 gaussian; 3) most diffuse part is 1 gaussian.
#
# 3.$\space$ 1) transparent: no conjugation $\rightarrow$ c;
#
# 5) two group: (1) 229 nm ($ε_{max}$~12600): unsaturated $\pi\pi^{*}$; (2) 327 nm ($ε_{max}$ ~ 98): unsaturated with heteroatoms $\rightarrow$  e
#
# 3) 277 nm ($ε_{max}$~19): C=O $n\pi^*$ weak intensity at 260-300 nm $\rightarrow$  b
#
# d with more conjugation $\rightarrow$  4) and a $\rightarrow$  2)
#
# 4.$\space$  $\nu=\frac{1}{2 \pi} \sqrt{\frac{k}{\mu}}$; $\begin{aligned} \mu &=\frac{235* 2}{237} > \mu =\frac{238* 1}{239} \end{aligned}$ so a) change cause a bigger change in the vibrational frequency.
#
# __Optional__
#
# O1.$\space$  <img src="./QM_HW7_O1.png" alt="drawing" width="400"/>
#
# $\quad\quad\quad\quad\quad\quad\quad\quad\quad\chi(\text {per atom})\quad   6 \quad 0 \quad0 \quad2 \quad0\quad 6\quad 2 \quad0 $
#
# $\quad\quad\quad\quad\quad\quad$ character of $x, y, z: \quad   3 -1 -1 -1 -3\quad 1\quad 1 \quad1$
#
# $m_{A_{g}}=\frac{1}{8}(18-2+6+2)=3$
#
# $m_{B 1 g}=\frac{1}{8}(18+2+6-2)=3$
#
# $m_{B 2 g}=\frac{1}{8}(18+2-6+2)=2$
#
# $m_{B 3 g}=\frac{1}{8}(18-2-2-6)=1$
#
# $m_{A u}=\frac{1}{8}(18-2-2-6)=1$
#
# $m_{B 1 u}=\frac{1}{8}(18+2-6+2)=2$
#
# $m_{B 2 u}=\frac{1}{8}(18+2+6-2)=3$
#
# $m_{B 3 u}=\frac{1}{8}(18-2+2+6)=3$
#
# $\Gamma_{\text {cart }}=3 A_{g}+3 B_{1{g}}+2 B_{2 g}+B_{3 g}+A_{u}+2 B_{\text {lu }}+3 B_{2 u }+3 B_{3u }$
#
# O2. ++ $\rightarrow$ diffuse function for each heavy atom and diffuse function for each hydrogen atom.
#
# ** $\rightarrow$ polarizing function for each heavy atom and polarizing function for each hydrogen atom.
#
# STO-nG, n value represents the number of Gaussian primitive functions comprising a single basis function (Slater Type Orbital).
#
# ___
#
# ---
#
# ## Extra Problems for Spectroscopy
#
# 1.$\space$ Using unpolar solvent for isoprene and butanone. Record signal position for both. Then using polar solvent. For isoprene ($\pi\pi*$), polar solvent will induce bathochromic displacement ($\lambda $ increase); for butanone ($n\pi*$), polar solvent will induce hypsochromic displacement ($\lambda $ decrease)
#
# 2.$\space$ IR. See below.
# <img src="./QM_Extra3_2_2.png" alt="drawing" width="400"/>
# <img src="./QM_Extra3_2_1.png" alt="drawing" width="400"/>
#
# 3.$\space$ At OH band, there are sharper peaks for 1,2-dihydroxybenzene because its intramolecular hydrogen bonding.
#
# <img src="./QM_Extra3_3_1.png" alt="drawing" width="400"/>
# <img src="./QM_Extra3_3_2.png" alt="drawing" width="400"/>
#
# 4.$\space$ $\space$
#
# <img src="./QM_Extra3_4_1.png" alt="drawing" width="400"/>
# <img src="./QM_Extra3_4_2.png" alt="drawing" width="200"/>
#
# 5.$\space$
#
# <img src="./QM_Extra3_5_1.png" alt="drawing" width="400"/>
